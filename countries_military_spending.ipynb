# %% [markdown]
# <a href="https://colab.research.google.com/github/juanlopez91/countries_military_spending/blob/main/countries_military_spending.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('SIPRI Military Expenditure Database.xlsx')

# %%
df
# Out:
#       Year      Country  Spending (2020 USD)  Percent of GDP  \
# 0     1988  Afghanistan                  NaN             NaN
# 1     1989  Afghanistan                  NaN             NaN
# 2     1990  Afghanistan                  NaN             NaN
# 3     1991  Afghanistan                  NaN             NaN
# 4     1992  Afghanistan                  NaN             NaN
# ...    ...          ...                  ...             ...
# 5877  2017     Zimbabwe           571.920778        0.003878
# 5878  2018     Zimbabwe           638.310913        0.003093
# 5879  2019     Zimbabwe           796.573534        0.005348
# 5880  2020     Zimbabwe             8.622460        0.000054
# 5881  2021     Zimbabwe            34.175047        0.000135
#
#       Percent of Government Spending  Spending per Capita
# 0                                NaN                  NaN
# 1                                NaN                  NaN
# ...

# %%
df.isna().sum()
# Out:
# Year                                 0
# Country                              0
# Spending (2020 USD)               1019
# Percent of GDP                    1001
# Percent of Government Spending    1672
# Spending per Capita               1047
# dtype: int64

# %%
df=df[(df['Year']>=2000) & (df['Year']<=2020)]

# %%
df
# Out:
#       Year      Country  Spending (2020 USD)  Percent of GDP  \
# 12    2000  Afghanistan                  NaN             NaN
# 13    2001  Afghanistan                  NaN             NaN
# 14    2002  Afghanistan                  NaN             NaN
# 15    2003  Afghanistan                  NaN             NaN
# 16    2004  Afghanistan           194.554838        0.024313
# ...    ...          ...                  ...             ...
# 5876  2016     Zimbabwe           616.157340        0.017210
# 5877  2017     Zimbabwe           571.920778        0.003878
# 5878  2018     Zimbabwe           638.310913        0.003093
# 5879  2019     Zimbabwe           796.573534        0.005348
# 5880  2020     Zimbabwe             8.622460        0.000054
#
#       Percent of Government Spending  Spending per Capita
# 12                               NaN                  NaN
# 13                               NaN                  NaN
# ...

# %%
df.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df.isna().sum()
# Out:
# Year                              0
# Country                           0
# Spending (2020 USD)               0
# Percent of GDP                    0
# Percent of Government Spending    0
# Spending per Capita               0
# dtype: int64

# %%
df
# Out:
#       Year      Country  Spending (2020 USD)  Percent of GDP  \
# 16    2004  Afghanistan           194.554838        0.024313
# 17    2005  Afghanistan           175.199533        0.019921
# 18    2006  Afghanistan           177.118535        0.018962
# 19    2007  Afghanistan           272.650828        0.025663
# 20    2008  Afghanistan           237.612426        0.023355
# ...    ...          ...                  ...             ...
# 5876  2016     Zimbabwe           616.157340        0.017210
# 5877  2017     Zimbabwe           571.920778        0.003878
# 5878  2018     Zimbabwe           638.310913        0.003093
# 5879  2019     Zimbabwe           796.573534        0.005348
# 5880  2020     Zimbabwe             8.622460        0.000054
#
#       Percent of Government Spending  Spending per Capita
# 16                          0.161343             5.059714
# 17                          0.126898             4.783940
# ...

# %%
spendingpc=df.groupby(['Country'])['Spending per Capita'].mean()

# %%
spendingpc
# Out:
# Country
# Afghanistan      6.981845
# Albania         50.151564
# Algeria        168.842328
# Angola         102.163309
# Argentina       79.755649
#                   ...
# Uzbekistan      11.059604
# Viet Nam        32.591132
# Yemen           50.219165
# Zambia          19.214658
# Zimbabwe        20.702928
# Name: Spending per Capita, Length: 157, dtype: float64

# %%
spendingpc.plot(kind='bar', title = 'Mean Military spending per Capita 2000-2020 (USD)', figsize = (20,10), cmap='Dark2', rot = 90)
